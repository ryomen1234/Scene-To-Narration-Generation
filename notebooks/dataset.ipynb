# %%
import json 
from pathlib import Path
import os

# %%
print(os.getcwd())
# Out:
# e:\project_archive\Scene-To-Narration-Generation

# %%
os.chdir("..")

# %%
data_path = Path("data/processed/dataset_encoded.json")
print(data_path.exists())
# Out:
# True

# %%
with open(data_path, "r") as f:
    data = json.load(f)

data[0]
# Out:
# {'images': ['data/raw/Images/2623560640_0445c9a138.jpg',
#   'data/raw/Images/3139160252_75109e9e05.jpg',
#   'data/raw/Images/2730819220_b58af1119a.jpg',
#   'data/raw/Images/241346402_5c070a0c6d.jpg',
#   'data/raw/Images/3611603026_9112b0c53f.jpg'],
#  'tokens': [1,
#   80,
#   107,
#   39,
#   4,
#   94,
#   3,
#   113,
#   5,
#   3,
#   3,
#   258,
#   5,
#   3,
#   6,
#   81,
#   29,
#   79,
#   152,
#   34,
#   248,
#   116,
#   71,
#   3,
#   7,
#   102,
#   8,
#   5,
#   3,
#   6,
#   5,
#   96,
#   28,
#   3,
#   51,
#   9,
#   10,
#   3,
#   8,
#   10,
#   27,
#   5,
#   31,
#   7,
#   275,
#   21,
#   5,
#   78,
#   317,
#   150,
#   3,
#   5,
#   69,
#   4,
#   5,
#   127,
#   3,
#   3,
#   114,
#   9,
#   5,
#   3,
#   3,
#   2]}

# %%
data[0]["images"]
# Out:
# ['data/raw/Images/2623560640_0445c9a138.jpg',
#  'data/raw/Images/3139160252_75109e9e05.jpg',
#  'data/raw/Images/2730819220_b58af1119a.jpg',
#  'data/raw/Images/241346402_5c070a0c6d.jpg',
#  'data/raw/Images/3611603026_9112b0c53f.jpg']

# %%
data[0]["tokens"]

# %%
max_len = 10
token = [1,3,2,4]

token = token + (max_len - len(token))*[0]
token
# Out:
# [1, 3, 2, 4, 0, 0, 0, 0, 0, 0]
